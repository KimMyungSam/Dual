# %% [markdown]
# 5. STOP LOSS & SYSTEM LOSS & 7개월평균 절대모멘텀

# %% [markdown]
# 월별손익   월별손실   월별이익
#
# -5%보다 작은 경우   -3%보다 작은 경우
#
#
# KODEX200   KODEX200   KODEX200   KODEX200   KODEX200
#
# count
#
# 108
#
# count
#
# 44
#
# count
#
# 62
#
# count
#
# 7
#
# count
#
# 18
#
# mean
#
# 0.442199
#
# mean
#
# -3.155114
#
# mean
#
# 3.009395
#
# mean
#
# -8.308678
#
# mean
#
# -5.594257
#
# std
#
# 3.897445
#
# std
#
# 2.814851
#
# std
#
# 2.240615
#
# std
#
# 2.89225
#
# std
#
# 2.856695
#
# min
#
# -12.673763
#
# min
#
# -12.673763
#
# min
#
# 0.016676
#
# min
#
# -12.673763
#
# min
#
# -12.673763
#
# 25%
#
# -2.135589
#
# 25%
#
# -3.84753
#
# 25%
#
# 1.221081
#
# 25%
#
# -9.941874
#
# 25%
#
# -6.077135
#
# 50%
#
# 0.58392
#
# 50%
#
# -2.47075
#
# 50%
#
# 2.693756
#
# 50%
#
# -7.516082
#
# 50%
#
# -4.653489
#
# 75%
#
# 2.931166
#
# 75%
#
# -0.965733
#
# 75%
#
# 4.019169
#
# 75%
#
# -6.054256
#
# 75%
#
# -3.440991
#
# max
#
# 9.053045
#
# max
#
# -0.167634
#
# max
#
# 9.053045
#
# max
#
# -5.978639
#
# max
#
# -3.262808

# %%
월별손실과 이익을 따져보면 -5%이하 손실이 8번 발생했고 이것이 전체적인 포트폴리오 실적에 영향을 준다.
그래서, 월단위 투자시 STOP LOSS를 -5%이하로 걸고, 실전에서 1일 단위 가격 모니터링을 하고 -5%손실이 나면 매도후 기간중 재진입 하지 않고
월말 리밸런싱때 재진입 한다.
