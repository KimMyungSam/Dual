# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("KODEX200_monthly_data.csv", encoding="utf-8")

# %%
df.head()
# Out:
#          Date   Open   High    Low  Close   Volume    Change
# 0  2010-01-29  19052  19066  18668  18742  2717811 -0.026996
# 1  2010-02-26  18611  18683  18514  18559   974615  0.000431
# 2  2010-03-31  19853  19858  19729  19789   883019 -0.003776
# 3  2010-04-30  20331  20403  20313  20377   758179  0.007814
# 4  2010-05-31  18887  19126  18882  19134  1979678  0.012220

# %%
kodex200 = df[["Date","Close"]]
kodex200.index = kodex200["Date"]
del kodex200["Date"]

# %% [markdown]
# ### 12개월 평균모멘텀 스코어 구하기

# %%
# 평균모멘텀 구하기
def 평균모멘텀구하기(data,month):
    result = 0
    for i in range(1,(month+1),1):
        result = data / data.shift(i) + result
    score = pd.DataFrame(result/month, index=data.index,columns=["score"]) 
    return score

# 평균모멘텀 스코어 구하기
def 평균모멘텀스코어구하기(data,month):
    result = 0
    for i in range(1,(month+1),1):
        result = np.where(data / data.shift(i) > 1,1,0) + result
    score = pd.DataFrame(result/month, index=data.index,columns=["score"]) 
    return score

# %%
# 현금투자할 상수 = 현금비율 0.5는 50%를 뜻함.
cash = 0.5
# 평균모멘텀스코어구하기
score12 = 평균모멘텀스코어구하기(kodex200["Close"],12)
# 평균모멘텀스코어와 종목["Close"] 합침
momentum12 = pd.concat([kodex200, score12], axis=1)

# %%
#주식투자 비율 = 주식 평균모멘텀 스코어 / (주식 평균모멘텀 스코어 + 현금상수)
stock_rate = momentum12["score"] / (cash + momentum12["score"])
#현금보유 비율 = 1 - 주식비율
cash_rate = 1 - stock_rate

# %% [markdown]
# ### 전략 수익곡선 6개월 평가

# %%
score = 평균모멘텀구하기(kodex200["Close"],12)
#score6 = 평균모멘텀스코어구하기(momentum12,6)
# momentum6 = pd.concat([momentum12, score6], axis=1)
score
# Out:
#            score
# Date
# 2010-01-29   NaN
# 2010-02-26   NaN
# 2010-03-31   NaN
# 2010-04-30   NaN
# 2010-05-31   NaN
# 2010-06-30   NaN
# 2010-07-30   NaN
# 2010-08-31   NaN
# 2010-09-30   NaN
# 2010-10-29   NaN
# 2010-11-30   NaN
# 2010-12-31   NaN
# 2011-01-31   NaN
# 2011-02-28   NaN
# 2011-03-31   NaN
# 2011-04-29   NaN
# 2011-05-31   NaN
# 2011-06-30   NaN
# 2011-07-29   NaN
# 2011-08-31   NaN
# 2011-09-30   NaN
# 2011-10-31   NaN
# 2011-11-30   NaN
# 2011-12-30   NaN
# 2012-01-31   NaN
# 2012-02-29   NaN
# 2012-03-30   NaN
# 2012-04-30   NaN
# 2012-05-31   NaN
# 2012-06-29   NaN
# ...          ...
# 2016-08-31   NaN
# 2016-09-30   NaN
# 2016-10-31   NaN
# 2016-11-30   NaN
# 2016-12-30   NaN
# 2017-01-31   NaN
# 2017-02-28   NaN
# 2017-03-31   NaN
# 2017-04-28   NaN
# 2017-05-31   NaN
# 2017-06-30   NaN
# 2017-07-31   NaN
# 2017-08-31   NaN
# 2017-09-29   NaN
# 2017-10-31   NaN
# 2017-11-30   NaN
# 2017-12-29   NaN
# 2018-01-31   NaN
# 2018-02-28   NaN
# 2018-03-30   NaN
# 2018-04-30   NaN
# 2018-05-31   NaN
# 2018-06-29   NaN
# 2018-07-31   NaN
# 2018-08-31   NaN
# 2018-09-28   NaN
# 2018-10-31   NaN
# 2018-11-30   NaN
# 2018-12-31   NaN
# 2019-01-31   NaN
#
# [109 rows x 1 columns]

# %%
plt.title("KODEX200 Dual Momentum")
plt.plot(momentum12["score"])

# %%
fig = plt.figure()  # an empty figure with no axes
fig.suptitle('KDOEX200 Dual Momentum')  # Add a title so we know which it is
fig, ax = plt.subplots()
ax.plot(momentum12)
plt.show()
